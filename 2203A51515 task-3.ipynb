# %%
import pandas as pd
d=pd.read_csv('/content/2203A51515.csv')
print(d)
# Out:
#        Name  Marks
# 0   Anuraag     98
# 1    Bharat     88
# 2  Harshith     76
# 3     Rahul     84

# %%
d=pd.read_excel('/content/2203A51515.xlsx')
print(d)
# Out:
#        Name  Marks
# 0   Anuraag     98
# 1    Bharat     88
# 2  Harshith     76
# 3     Rahul     84

# %%
d=pd.read_csv('/content/2203A51515.tsv')
print(d)
# Out:
#     Name\tMarks
# 0   Anuraag\t98
# 1    Bharat\t88
# 2  Harshith\t76
# 3     Rahul\t84
